# %%
#load txt file
with open("../outputs/llm_test/openai_llm_test_case3_run2-max_token-16384.txt", 'r') as fn:
    data = fn.read()

data
# Out:
# 'System Prompt:\nYou\'re an embodied agent trapped in a simulated environment game popularly known as an escape room.         You will be provided with an obervation graph in json format representing the objects and their corresponding relationships within the room.         You\'ll be given a set of allowed actions. However, you cannot be violent or break things.         The allowed actions are represented in the format of \'action_name: action_index\', a complete list of allowed actions is as follows: {\'stand\': 1, \'walk\': 2, \'run\': 3, \'drive\': 4, \'grab\': 5, \'place\': 6, \'open\': 7, \'close\': 8, \'lookat\': 9, \'switch on\': 10, \'switch off\': 11, \'sit\': 12, \'sleep\': 13, \'eat\': 14, \'drink\': 15, \'clean\': 16, \'point\': 17, \'pull\': 18, \'push\': 19, \'cook\': 20, \'cut\': 21, \'pour\': 22, \'shower\': 23, \'dry\': 24, \'lock\': 25, \'unlock\': 26, \'fill\': 27, \'talk\': 28, \'laugh\': 29, \'angry\': 30, \'cry\': 31, \'call\': 32, \'interact\': 33, \'step_forw
# ...

# %%
fixed_action_ids = {
            "stand": 1, 
            "walk": 2, 
            "run": 3, 
            "drive": 4, 
            "grab": 5, 
            "place": 6, 
            "open": 7, 
            "close": 8, 
            "lookat": 9, 
            "switch on": 10, 
            "switch off": 11, 
            "sit": 12, 
            "sleep": 13, 
            "eat": 14, 
            "drink": 15, 
            "clean": 16, 
            "point": 17, 
            "pull": 18, 
            "push": 19, 
            "cook": 20, 
            "cut": 21, 
            "pour": 22, 
            "shower": 23, 
            "dry": 24, 
            "lock": 25, 
            "unlock": 26, 
            "fill": 27, 
            "talk": 28, 
            "laugh": 29, 
            "angry": 30, 
            "cry": 31, 
            "call": 32, 
            "interact": 33, 
            "step_forward": 34, 
            "step_backwards": 35, 
            "turn_left": 36, 
            "turn_right": 37}

def check_feasibility(action, graph):
    """check if the action is feasible in the current environment"""

    #currently a passthrough, will need to call communication API to unreal
    return True

# %%
#only process llm's output
message_begining = "LLM Output:"
message_end = "\n\n"
filtered_response = (data.split(message_begining)[1]).split(message_end)[0]
intended_actions = filtered_response.split("\n")

#build action set
#and check for feasibility
action_list = [action.replace('  ', '').split(' ') for action in intended_actions \
    if action.split(' ')[0].lower() in fixed_action_ids.keys() and check_feasibility(action, graph=None)]

# %%
action_list
# Out:
# [['Open', 'Cube'],
#  ['Grab', 'SM_Wire_A01'],
#  ['Grab', 'SM_Wire_A2'],
#  ['Grab', 'SM_TableDining12'],
#  ['Grab', 'SM_Chair01'],
#  ['Grab', 'SM_Chair2'],
#  ['Grab', 'SM_TableDining13'],
#  ['Grab', 'SM_Earphone01Base'],
#  ['Grab', 'SM_Earphone01Left'],
#  ['Grab', 'SM_Earphone01Right'],
#  ['Grab', 'SM_Food_Leftover_AO1_N1'],
#  ['Grab', 'SM_Food_Leftover_CO1_N1'],
#  ['Grab', 'SM_Food_Leftover_EO1_N1'],
#  ['Grab', 'SM_Food_Leftover_FO1_N1'],
#  ['Grab', 'SM_Food_Leftover_GO1_N1'],
#  ['Grab', 'SM_BooksPamphlets_G01_N1'],
#  ['Grab', 'SM_BooksPamphlets_K01_N1'],
#  ['Grab', 'SM_Laptop02'],
#  ['Grab', 'SM_Screen04'],
#  ['Grab', 'SM_TV02'],
#  ['Grab', 'SM_PCKeyboard03'],
#  ['Grab', 'SM_PCMouse03'],
#  ['Grab', 'SM_DeskLamp_A01_N1'],
#  ['Grab', 'SM_DeskLamp_A01_N2'],
#  ['Grab', 'SM_DeskLamp_A01_N3']]

# %%
b = {
    "KswainEscapeRoom2": [
        {
            "container": 0.0,
            "id": 0.0,
            "name": "Cube",
            "relation": [],
            "state": [""],
            "transform": ["X=-83.539 Y=1093.615 Z=50.650", "P=0.000000 Y=0.000000 R=0.000000", "X=161.750 Y=165.000 Z=1.000"]
        },
        {
            "container": 0.0,
            "id": 1.0,
            "name": "SM_Wire_A01",
            "relation": ["SM_Wire_A01 supported by Cube", "SM_Wire_A01 inside Cube"],
            "state": [""],
            "transform": ["X=102.545 Y=1060.646 Z=100.380", "P=0.000000 Y=-179.999969 R=0.000000", "X=1.000 Y=1.000 Z=1.000"]
        },
        {
            "container": 0.0,
            "id": 2.0,
            "name": "SM_Wire_A2",
            "relation": ["SM_Wire_A2 supported by Cube", "SM_Wire_A2 inside Cube"],
            "state": [""],
            "transform": ["X=-26.153 Y=920.610 Z=100.650", "P=0.000000 Y=-50.000027 R=0.000000", "X=0.950 Y=0.950 Z=0.950"]
        },
        {
            "container": 0.0,
            "id": 3.0,
            "name": "SM_TableDining11",
            "relation": [],
            "state": [""],
            "transform": ["X=40.337 Y=1107.983 Z=100.650", "P=0.000000 Y=-89.999999 R=0.000000", "X=1.000 Y=1.000 Z=1.000"]
        },
        {
            "container": 0.0,
            "id": 4.0,
            "name": "SM_TableDining12",
            "relation": ["SM_TableDining12 supported by Cube", "SM_TableDining12 inside Cube"],
            "state": [""],
            "transform": ["X=-105.961 Y=1170.790 Z=100.650", "P=0.000000 Y=0.000000 R=0.000000", "X=1.000 Y=1.000 Z=1.000"]
        },
        {
            "container": 0.0,
            "id": 5.0,
            "name": "SM_TV02",
            "relation": ["SM_TV02 supported by SM_TableDining11", "SM_TV02 inside SM_TableDining11"],
            "state": [""],
            "transform": ["X=62.514 Y=1109.903 Z=175.650", "P=0.000000 Y=89.999999 R=0.000000", "X=1.000 Y=1.000 Z=1.000"]
        },
        {
            "container": 0.0,
            "id": 6.0,
            "name": "SM_PCKeyboard03",
            "relation": ["SM_PCKeyboard03 supported by SM_TableDining11", "SM_PCKeyboard03 inside SM_TableDining11"],
            "state": [""],
            "transform": ["X=23.870 Y=1103.363 Z=175.650", "P=0.000000 Y=79.999999 R=0.000000", "X=1.000 Y=1.000 Z=1.000"]
        },
        {
            "container": 0.0,
            "id": 7.0,
            "name": "SM_PCMouse03",
            "relation": ["SM_PCMouse03 supported by SM_TableDining11", "SM_PCMouse03 inside SM_TableDining11"],
            "state": [""],
            "transform": ["X=20.443 Y=1136.963 Z=175.650", "P=0.000000 Y=60.000000 R=0.000000", "X=1.000 Y=1.000 Z=1.000"]
        },
        {
            "container": 0.0,
            "id": 8.0,
            "name": "SM_Chair01",
            "relation": ["SM_Chair01 supported by Cube", "SM_Chair01 inside Cube"],
            "state": [""],
            "transform": ["X=-42.234 Y=1074.193 Z=100.650", "P=0.000000 Y=-55.000000 R=0.000000", "X=1.000 Y=1.000 Z=1.000"]
        },
        {
            "container": 0.0,
            "id": 9.0,
            "name": "SM_Screen04",
            "relation": [],
            "state": [""],
            "transform": ["X=6.768 Y=1195.785 Z=175.650", "P=0.000000 Y=179.999999 R=0.000000", "X=1.000 Y=1.000 Z=1.000"]
        },
        {
            "container": 0.0,
            "id": 10.0,
            "name": "SM_DeskLamp_A01_N1",
            "relation": [],
            "state": [""],
            "transform": ["X=66.946 Y=1194.524 Z=175.656", "P=0.007753 Y=133.196094 R=-0.048009", "X=1.347 Y=1.347 Z=1.347"]
        },
        {
            "container": 0.0,
            "id": 11.0,
            "name": "SM_DeskLamp_A01_N2",
            "relation": [],
            "state": [""],
            "transform": ["X=-140.392 Y=1203.429 Z=175.656", "P=0.007753 Y=-166.803906 R=-0.048009", "X=1.347 Y=1.347 Z=1.347"]
        },
        {
            "container": 0.0,
            "id": 12.0,
            "name": "SM_Chair2",
            "relation": ["SM_Chair2 supported by Cube", "SM_Chair2 inside Cube"],
            "state": [""],
            "transform": ["X=-114.410 Y=1102.185 Z=100.650", "P=0.000000 Y=-0.000000 R=0.000000", "X=1.000 Y=1.000 Z=1.000"]
        },
        {
            "container": 0.0,
            "id": 13.0,
            "name": "SM_DeskLamp_A01_N3",
            "relation": [],
            "state": [""],
            "transform": ["X=21.224 Y=923.581 Z=175.656", "P=0.007753 Y=78.196095 R=-0.048009", "X=1.347 Y=1.347 Z=1.347"]
        },
        {
            "container": 0.0,
            "id": 14.0,
            "name": "SM_TableDining13",
            "relation": ["SM_TableDining13 supported by Cube", "SM_TableDining13 inside Cube"],
            "state": [""],
            "transform": ["X=-24.663 Y=917.983 Z=100.650", "P=0.000000 Y=-139.999999 R=0.000000", "X=0.500 Y=1.000 Z=1.000"]
        },
        {
            "container": 0.0,
            "id": 15.0,
            "name": "SM_BooksPamphlets_K01_N1",
            "relation": [],
            "state": [""],
            "transform": ["X=15.000 Y=1155.000 Z=175.000", "P=0.000000 Y=-45.000000 R=0.000000", "X=1.000 Y=1.000 Z=1.000"]
        },
        {
            "container": 0.0,
            "id": 16.0,
            "name": "SM_Laptop02",
            "relation": [],
            "state": [""],
            "transform": ["X=-40.000 Y=925.000 Z=175.000", "P=0.000000 Y=55.000000 R=0.000000", "X=1.000 Y=1.000 Z=1.000"]
        },
        {
            "container": 0.0,
            "id": 17.0,
            "name": "SM_Earphone01Base",
            "relation": ["SM_Earphone01Base supported by SM_TableDining13", "SM_Earphone01Base inside SM_TableDining13"],
            "state": [""],
            "transform": ["X=-30.000 Y=950.000 Z=175.431", "P=0.000000 Y=0.000000 R=0.000000", "X=1.000 Y=1.000 Z=1.000"]
        },
        {
            "container": 0.0,
            "id": 18.0,
            "name": "SM_Earphone01Left",
            "relation": ["SM_Earphone01Left supported by SM_TableDining13", "SM_Earphone01Left inside SM_TableDining13"],
            "state": [""],
            "transform": ["X=-23.411 Y=954.716 Z=175.650", "P=0.000000 Y=0.000000 R=0.000000", "X=1.000 Y=1.000 Z=1.000"]
        },
        {
            "container": 0.0,
            "id": 19.0,
            "name": "SM_Earphone01Right",
            "relation": ["SM_Earphone01Right supported by SM_TableDining13", "SM_Earphone01Right inside SM_TableDining13"],
            "state": [""],
            "transform": ["X=-22.591 Y=958.671 Z=175.650", "P=0.000000 Y=99.999999 R=0.000000", "X=1.000 Y=1.000 Z=1.000"]
        },
        {
            "container": 0.0,
            "id": 20.0,
            "name": "SM_BooksPamphlets_G01_N1",
            "relation": [],
            "state": [""],
            "transform": ["X=-112.764 Y=1157.299 Z=175.650", "P=0.000000 Y=-84.999999 R=0.000000", "X=1.000 Y=1.000 Z=1.000"]
        },
        {
            "container": 0.0,
            "id": 21.0,
            "name": "SM_Food_Leftover_GO1_N1",
            "relation": [],
            "state": [""],
            "transform": ["X=-135.000 Y=1150.000 Z=175.000", "P=0.000000 Y=-139.999999 R=0.000000", "X=1.000 Y=1.000 Z=1.000"]
        },
        {
            "container": 0.0,
            "id": 22.0,
            "name": "SM_Food_Leftover_AO1_N1",
            "relation": ["SM_Food_Leftover_AO1_N1 supported by SM_TableDining12", "SM_Food_Leftover_AO1_N1 inside SM_TableDining12"],
            "state": [""],
            "transform": ["X=-35.000 Y=1145.000 Z=175.654", "P=0.000000 Y=0.000000 R=0.000000", "X=1.000 Y=1.000 Z=1.000"]
        },
        {
            "container": 0.0,
            "id": 23.0,
            "name": "SM_Food_Leftover_EO1_N1",
            "relation": [],
            "state": [""],
            "transform": ["X=68.000 Y=1013.000 Z=176.000", "P=0.000000 Y=10.000000 R=0.000000", "X=1.000 Y=1.000 Z=1.000"]
        },
        {
            "container": 0.0,
            "id": 24.0,
            "name": "SM_Food_Leftover_FO1_N1",
            "relation": [],
            "state": [""],
            "transform": ["X=69.000 Y=1027.000 Z=176.000", "P=0.000000 Y=69.999999 R=0.000000", "X=1.000 Y=1.000 Z=1.000"]
        },
        {
            "container": 0.0,
            "id": 25.0,
            "name": "SM_Food_Leftover_CO1_N1",
            "relation": ["SM_Food_Leftover_CO1_N1 supported by SM_Food_Leftover_AO1_N1", "SM_Food_Leftover_CO1_N1 inside SM_Food_Leftover_AO1_N1"],
            "state": [""],
            "transform": ["X=-45.000 Y=1140.000 Z=176.000", "P=0.000000 Y=-179.999999 R=0.000000", "X=1.000 Y=1.000 Z=1.000"]
        }
    ]
}

# %%
[b['KswainEscapeRoom2'][i]['name'] for i in range(len(b['KswainEscapeRoom2']))]
# Out:
# ['Cube',
#  'SM_Wire_A01',
#  'SM_Wire_A2',
#  'SM_TableDining11',
#  'SM_TableDining12',
#  'SM_TV02',
#  'SM_PCKeyboard03',
#  'SM_PCMouse03',
#  'SM_Chair01',
#  'SM_Screen04',
#  'SM_DeskLamp_A01_N1',
#  'SM_DeskLamp_A01_N2',
#  'SM_Chair2',
#  'SM_DeskLamp_A01_N3',
#  'SM_TableDining13',
#  'SM_BooksPamphlets_K01_N1',
#  'SM_Laptop02',
#  'SM_Earphone01Base',
#  'SM_Earphone01Left',
#  'SM_Earphone01Right',
#  'SM_BooksPamphlets_G01_N1',
#  'SM_Food_Leftover_GO1_N1',
#  'SM_Food_Leftover_AO1_N1',
#  'SM_Food_Leftover_EO1_N1',
#  'SM_Food_Leftover_FO1_N1',
#  'SM_Food_Leftover_CO1_N1']

# %%
[action.split(' ') for action in intended_actions]
# Out:
# [['M'],
#  ['o'],
#  ['v'],
#  ['e'],
#  ['', ''],
#  ['t'],
#  ['o'],
#  ['', ''],
#  ['C'],
#  ['u'],
#  ['b'],
#  ['e'],
#  ['', ''],
#  ['', '']]
